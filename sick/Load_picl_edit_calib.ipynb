# %%
import pickle
import os

# %%
file_gt='frustum_carpedcyc_gt.pickle'

# %%
file='frustum_carpedcyc_val_rgb_detection.pickle'
with open(file,'rb') as f:
    a=pickle.load(f)
a
# Out:
# [2,
#  34,
#  9,
#  9,
#  24,
#  24,
#  10,
#  10,
#  3,
#  3,
#  3,
#  7,
#  7,
#  7,
#  17,
#  17,
#  4,
#  35,
#  35,
#  43,
#  45,
#  25,
#  25,
#  30,
#  37,
#  37,
#  38,
#  38,
#  48,
#  47,
#  20,
#  20,
#  20,
#  15,
#  15,
#  41,
#  41,
#  13,
#  13,
#  32,
#  32,
#  27,
#  28,
#  16,
#  16,
#  36,
#  36,
#  39,
#  12,
#  12,
#  1,
#  5,
#  5,
#  23,
#  23,
#  11,
#  11,
#  44,
#  26,
#  33,
#  33,
#  49,
#  46,
#  19,
#  19,
#  29,
#  29,
#  22,
#  22,
#  14,
#  14,
#  18,
#  18,
#  8,
#  8,
#  8,
#  6,
#  6,
#  21,
#  21,
#  50,
#  40,
#  40,
#  42,
#  42,
#  31]

# %%
with open(file_gt,'rb') as f:
    b=pickle.load(f)
b
# Out:
# [1,
#  2,
#  4,
#  4,
#  4,
#  5,
#  6,
#  6,
#  6,
#  6,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  19,
#  19,
#  19,
#  19,
#  19,
#  20,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  23,
#  24,
#  24,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  27,
#  28,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  33,
#  33,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  40,
#  40,
#  40,
#  42,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  50,
#  50,
#  50,
#  50,
#  52,
#  52,
#  52,
# ...

# %%
import numpy as np
camera_intrinsic = np.array([[538.001770,  0.0e+00,    318.06800908], 
                             [0.0e+00,    538.001770,  254.635299],
                             [0.0e+00,      0.0e+00,      1.0e+00]])

# %%
np.linalg.inv(camera_intrinsic)
# Out:
# array([[ 0.00185873,  0.        , -0.59120253],
#        [ 0.        ,  0.00185873, -0.47329826],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
folder_path='calib'
for file_name in os.listdir(folder_path):
    file = open(folder_path+'/'+file_name,'r')
    lines=file.readlines()
    lines[0] = 'P0: 1.000000000000e+00 0.000000000000e+00 0.000000000000e+00 0.000000000000e+00 0.000000000000e+00 1.000000000000e+00 0.000000000000e+00 0.000000000000e+00 0.000000000000e+00 0.000000000000e+00 1.000000000000e+00 0.000000000000e+00/n'
    file = open(folder_path+'/'+file_name, "w")
    file.writelines(lines)
    file.close()
